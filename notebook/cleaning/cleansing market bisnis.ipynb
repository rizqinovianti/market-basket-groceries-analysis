# %% [markdown]
# # LOAD DATASET

# %%
import pandas as pd
df = pd.read_csv("Market Basket Analysis- Groceries.csv")
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
print("Jumlah Baris :", df.shape[0])
print("Jumlah Kolom :", df.shape[1])
# Out:
# Jumlah Baris : 38765
# Jumlah Kolom : 3

# %% [markdown]
# # CEK & HANDLE ISSUE DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 908.7+ KB

# %%
# Cek missing value
df.isnull().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
# Cek duplikat
print("Jumlah Duplicate :", df.duplicated().sum())
# Out:
# Jumlah Duplicate : 759

# %%
# Ubah tipe data date
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Cek pelanggan unik
df['Member_number'].unique().shape
# Out:
# (3898,)

# %%
# Cek deskripsi produk
df['itemDescription'].describe()
# Out:
# count          38765
# unique           167
# top       whole milk
# freq            2502
# Name: itemDescription, dtype: object

# %%
# Cek jumlah masing masing produk
df['itemDescription'].value_counts()
# Out:
# itemDescription
# whole milk               2502
# other vegetables         1898
# rolls/buns               1716
# soda                     1514
# yogurt                   1334
#                          ...
# rubbing alcohol             5
# bags                        4
# baby cosmetics              3
# kitchen utensil             1
# preservation products       1
# Name: count, Length: 167, dtype: int64

# %% [markdown]
# # FEATURE ENGINEERING

# %% [markdown]
# 1. Membuat transaction ID

# %%
df["Transaction_ID"] = (
    df["Member_number"].astype(str)
    + "_"
    + df["Date"].astype(str)
)

# %% [markdown]
# 3. Month

# %%
df["Month"] = pd.to_datetime(df["Date"]).dt.month_name()

# %% [markdown]
# 4. Day_Name

# %%
df["Day_Name"] = pd.to_datetime(df["Date"]).dt.day_name()

# %% [markdown]
# 5. Basket_Size

# %%
basket_size = (
    df.groupby("Transaction_ID")
      .size()
      .reset_index(name="Basket_Size")
)

df = df.merge(basket_size, on="Transaction_ID", how="left")

# %% [markdown]
# # SIMPAN FILE

# %%
df.to_excel('Market_basket2.xlsx', index=False)
print("Datanya sudah berhasil disimpan jadi file")
# Out:
# Datanya sudah berhasil disimpan jadi file
